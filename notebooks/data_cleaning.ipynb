# %%
import sys
import os
import pandas as pd

# %%
# Append the project root path to sys.path
sys.path.append(os.path.abspath(".."))

# %%
from scripts.data_cleaning import DataCleaner

# %%
# Initialize DataCleaner
cleaner = DataCleaner(
    input_path="../data/raw/scraped_data.csv",
    output_path="../data/preprocessed/cleaned_telegram_data.csv"
)

# %%
# Load raw data using DataCleaner
df_raw = cleaner.load_csv()

# Display first 10 rows
df_raw.head(10)
# Out:
#       Channel Title Channel Username   ID  \
# 0  Doctors Ethiopia       @DoctorsET  864
# 1  Doctors Ethiopia       @DoctorsET  863
# 2  Doctors Ethiopia       @DoctorsET  862
# 3  Doctors Ethiopia       @DoctorsET  861
# 4  Doctors Ethiopia       @DoctorsET  860
# 5  Doctors Ethiopia       @DoctorsET  859
# 6  Doctors Ethiopia       @DoctorsET  848
# 7  Doctors Ethiopia       @DoctorsET  847
# 8  Doctors Ethiopia       @DoctorsET  846
# 9  Doctors Ethiopia       @DoctorsET  845
#
#                                              Message  \
# 0  https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2  ሞት በስኳር \n\nለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀን...
# 3  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ?\n\nሙ...
# 4  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
# 5  👇👇👇👇👇👇 https://youtu.be/-AR1KO2DbFw?si=47cXLZt...
# 6  ክረምቱን ስፖርት መስራት አስበው ጂም ለመግባት ካልቻሉ ባሉበት ቦታ ሆነው...
# 7  ስፖርት የመስራት ሱስ ይኖር ይሆን?\n\nበአሁኑ ወቅት ብዙ የስፖርት መስ...
# ...

# %%
# Clean the raw DataFrame
df_cleaned = cleaner.clean_dataframe(df_raw)

# Display cleaned dataset
df_cleaned.head(10)
# Out:
#       channel_title channel_username  message_id  \
# 0  Doctors Ethiopia       @DoctorsET         864
# 1  Doctors Ethiopia       @DoctorsET         863
# 2  Doctors Ethiopia       @DoctorsET         862
# 3  Doctors Ethiopia       @DoctorsET         861
# 4  Doctors Ethiopia       @DoctorsET         860
# 5  Doctors Ethiopia       @DoctorsET         859
# 6  Doctors Ethiopia       @DoctorsET         848
# 7  Doctors Ethiopia       @DoctorsET         847
# 8  Doctors Ethiopia       @DoctorsET         846
# 9  Doctors Ethiopia       @DoctorsET         845
#
#                                              message  \
# 0  https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2  ሞት በስኳር  ለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀንሰው ...
# 3  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ? ሙሉ ቪ...
# 4  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
# 5   https://youtu.be/-AR1KO2DbFw?si=47cXLZtlmhx1N...
# ...

# %%
# Check for missing values in the cleaned DataFrame
missing_values = df_cleaned.isnull().sum()
missing_values[missing_values > 0]  # Display only columns with missing values
# Out:
# Series([], dtype: int64)

# %%
# save the cleaned DataFrame
cleaner.save_csv(df_cleaned)
